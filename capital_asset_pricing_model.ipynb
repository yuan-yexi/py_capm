# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import yfinance as yf 
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn')

# %%
stock =  ['AAPL','IBM','MSFT','INTC','^GSPC']
start = datetime.datetime(2020,1,1)
end = datetime.datetime(2021,4,9)
SP = yf.download(stock, start=start, end=end, interval='1d')
SP_close = SP['Close']
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
start=1
for i in stock:
    plt.figure(figsize=(10,6))
    plt.subplot(5,1,start)
    plt.plot(SP_close.loc[:,i])
    plt.title(i+' Prices')
    plt.ylabel('$')
    plt.xlabel('Date')
    start=start+1
plt.show()

# %%
from fredapi import Fred
fred = Fred(api_key='9e5fb3623592e925c32bef099619225a')

# %%
DGS3MO=fred.get_series('DGS3MO')

# %%
plt.plot(DGS3MO)
plt.title('DGS3MO')
plt.ylabel('%')
plt.xlabel('Date')
plt.show()
